# %%
import torch
from sanskrit_tagger.tagger_factory import get_segmenter

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = torch.hub.load('koleslena/sanskrit_nlp_models', 'segmenter_model', version='releases.csv', device=device)

segmenter = get_segmenter(model)

test_splitter_sentences = ["agnihotrātsamutthāya harṣeṇa mahatānvitā",
                            "uvāca cainaṁ varadā vacanaṁ pārthivaṁ tadā"]

right = """
        agnihotrāt samutthāya harṣeṇa mahatā anvitā |
        uvāca ca enam vara-dā vacanam pārthivam tadā 
        """

for sent, predicted in zip(test_splitter_sentences, segmenter(test_splitter_sentences)):
    print(f"Input:  {sent}")
    print(f"Output: {predicted}")
# Out:
# Using cache found in /Users/elenko/.cache/torch/hub/koleslena_sanskrit_nlp_models_main
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 6
#       2 from sanskrit_tagger.tagger_factory import get_segmenter
#       4 device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# ----> 6 model = torch.hub.load('koleslena/sanskrit_nlp_models', 'segmenter_model', version='releases.csv', device=device)
#       8 segmenter = get_segmenter(model)
#      10 test_splitter_sentences = ["agnihotrātsamutthāya harṣeṇa mahatānvitā",
#      11                             "uvāca cainaṁ varadā vacanaṁ pārthivaṁ tadā"]
#
# File ~/projects/sanskrit_nlp_models/.venv/lib/python3.9/site-packages/torch/hub.py:647, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     637 if source == "github":
#     638     repo_or_dir = _get_cache_or_reload(
#     639         repo_or_dir,
#     640         force_reload,
#    (...)
#     644         skip_validation=skip_validation,
#     645     )
# --> 647 model = _load_local(repo_or_dir, model, *args, **kwargs)
#     648 return model
#
# File ~/projects/sanskrit_nlp_models/.venv/lib/python3.9/site-packages/torch/hub.py:679, in _load_local(hubconf_dir, model, *args, **kwargs)
#     676     hubconf_path = os.path.join(hubconf_dir, MODULE_HUBCONF)
#     677     hub_module = _import_module(MODULE_HUBCONF, hubconf_path)
# --> 679     entry = _load_entry_from_hubconf(hub_module, model)
#     680     model = entry(*args, **kwargs)
#     682 return model
#
# File ~/projects/sanskrit_nlp_models/.venv/lib/python3.9/site-packages/torch/hub.py:387, in _load_entry_from_hubconf(m, model)
#     384 func = _load_attr_from_module(m, model)
#     386 if func is None or not callable(func):
# --> 387     raise RuntimeError(f"Cannot find callable {model} in hubconf")
#     389 return func
#
# RuntimeError: Cannot find callable segmenter_model in hubconf
